# %%
print("Saeed")
# Out:
# Saeed

# %%
corpus = """Hello Welcome to Saeedullah Practice, Students Please watch everythign.
So then you will able to do everything."""

# %%
corpus
# Out:
# 'Hello Welcome to Saeedullah Practice, Students Please watch everythign.\nSo then you will able to do everything.'

# %%
print(corpus)
# Out:
# Hello Welcome to Saeedullah Practice, Students Please watch everythign.
# So then you will able to do everything.

# %%
##Tokenization
## Sentence into --> Paragraphs

# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import nltk

nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
sent_tokenize(corpus)
# Out:
# ['Hello Welcome to Saeedullah Practice, Students Please watch everythign.',
#  'So then you will able to do everything.']

# %%
sentence = """Hi my name is Saeedullah. What's your's? tell me!. If anything i can help you?"""

# %%
docs = sent_tokenize(sentence)

# %%
docs
# Out:
# ['Hi my name is Saeedullah.',
#  "What's your's?",
#  'tell me!.',
#  'If anything i can help you?']

# %%
for doc in docs:
    print("--------------")
    print(doc)
# Out:
# --------------
#
# Hi my name is Saeedullah.
# --------------
# Whats yours?
# --------------
# tell me!.
# --------------
# If anything i can help you?

# %%
from nltk.tokenize import word_tokenize

# %%
wordslist = word_tokenize(sentence)

# %%
wordslist
# Out:
# ['Hi',
#  'my',
#  'name',
#  'is',
#  'Saeedullah',
#  '.',
#  'What',
#  "'s",
#  'your',
#  "'s",
#  '?',
#  'tell',
#  'me',
#  '!',
#  '.',
#  'If',
#  'anything',
#  'i',
#  'can',
#  'help',
#  'you',
#  '?']

# %%
for sent in docs:
    print(word_tokenize(sent))
# Out:
# ['Hi', 'my', 'name', 'is', 'Saeedullah', '.']
# ['What', "'s", 'your', "'s", '?']
# ['tell', 'me', '!', '.']
# ['If', 'anything', 'i', 'can', 'help', 'you', '?']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(sentence)
# Out:
# ['Hi',
#  'my',
#  'name',
#  'is',
#  'Saeedullah.',
#  'What',
#  "'s",
#  'your',
#  "'s",
#  '?',
#  'tell',
#  'me',
#  '!',
#  '.',
#  'If',
#  'anything',
#  'i',
#  'can',
#  'help',
#  'you',
#  '?']
