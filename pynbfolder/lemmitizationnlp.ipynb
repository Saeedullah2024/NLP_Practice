# %%
print("Saeed")

# %%
print("Saeed")
# Out:
# Saeed

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\kasf traders\\AppData\\Local\\Python\\pythoncore-3.14-64\\python.exe'

# %%
import nltk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import nltk
#
# ModuleNotFoundError: No module named 'nltk'

# %%
from nltk.stem import WordNetLemmatizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from nltk.stem import WordNetLemmatizer
#
# ModuleNotFoundError: No module named 'nltk'

# %%
lemmatizer = WordNetLemmatizer()

# %%
words = ["going" , "eaten" , "working" , "running" , "bad boy" , "good" , "funny" , "What" , "joke" , "history"]

# %%
for word in words:
    print(f"{word} -------> {lemmatizer.lemmatize(word , pos='v')}")
# Out:
# going -------> go
# eaten -------> eat
# working -------> work
# running -------> run
# bad boy -------> bad boy
# good -------> good
# funny -------> funny
# What -------> What
# joke -------> joke
# history -------> history
