# %%
print("Saeed")
# Out:
# Saeed

# %%
#First deactivate windows security by reg add "HKLM\SYSTEM\CurrentControlSet\Control\DeviceGuard\Scenarios\HypervisorEnforcedCodeIntegrity" /v Enabled /t REG_DWORD /d 0 /f
import spacy

# %%
###After Working activate windows security by reg add "HKLM\SYSTEM\CurrentControlSet\Control\DeviceGuard\Scenarios\HypervisorEnforcedCodeIntegrity" /v Enabled /t REG_DWORD /d 1 /f

# %%
nlp = spacy.load("en_core_web_sm")
